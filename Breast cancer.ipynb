# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Read Data

# %%
data=pd.read_csv("breast_cancer_detection.csv")

# %%
df = data.copy()

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# > Lets take a glance at our dataframe and see how it looks

# %% [markdown]
# # 3. Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.size
# Out:
# 18777

# %%
df.shape
# Out:
# (569, 33)

# %% [markdown]
# > We conlude that the shape of this dataframe is 569 X 33 and the size is 18777. With the help of DataFrame.info() we show that the datatypes and null values of the dataframe.

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# > There are one column, which has many null values even there are many columns, which is not using for the prediction so we might remove that for just smooth and accuratea prediction.

# %%
col=['radius_mean','diagnosis','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']
df1=df[col]

# %% [markdown]
# > We filter that data now we will apply Exploratory Data Analysis of this copy data.

# %%
df1.head()
# Out:
#    radius_mean diagnosis  texture_mean  perimeter_mean  area_mean  \
# 0        17.99         M         10.38          122.80     1001.0
# 1        20.57         M         17.77          132.90     1326.0
# 2        19.69         M         21.25          130.00     1203.0
# 3        11.42         M         20.38           77.58      386.1
# 4        20.29         M         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df1.tail()
# Out:
#      radius_mean diagnosis  texture_mean  perimeter_mean  area_mean  \
# 564        21.56         M         22.39          142.00     1479.0
# 565        20.13         M         28.25          131.20     1261.0
# 566        16.60         M         28.08          108.30      858.1
# 567        20.60         M         29.33          140.10     1265.0
# 568         7.76         B         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df1.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df1.shape
# Out:
# (569, 31)

# %%
df1.size
# Out:
# 17639

# %% [markdown]
# > We conlude that the shape of this dataframe is 569 X 31 and the size is 17639. With the help of DataFrame.describe() we show that the count, mean, standard deviation, max, min and median of the dataframe.

# %% [markdown]
# # 4. Graphical View

# %% [markdown]
# # Univariate analysis

# %%
df1.hist(bins=20,figsize=(15,15));

# %% [markdown]
# > This graphs represent histographs of each and every features. We conclude the skewnesses and Kurtosis even outliers.

# %% [markdown]
# # Biavariate Analysis

# %%
plt.figure(figsize=(20,20))
mask = np.zeros_like(df1.corr())
mask[np.triu_indices_from(mask, k = 1)] = True
sns.heatmap(data=df1.corr(),cmap = 'Blues',vmax = 1.0, vmin = -1.0, annot = True, annot_kws = {"size": 12}, mask = mask);

# %% [markdown]
# > Conclution:
#  - (1) The diagonal entries are all '1' which represents the correlation of the variable with itself. The dark blue squares represent the variables with strong positive correlation.The above plot shows that there is highest positive correlation (= 0.99) between the variables 'area_mean' and 'radius_mean'. These variables may involved in multicollinearity.
#  - (2) Correlation does not imply causation. In other words, if two variables are correlated, it does not mean that one variable caused the other.

# %% [markdown]
# # 5. Handling Outlier

# %%
plt.figure(figsize =(8,4))
sns.boxplot(x = 'area_mean', data=df1, orient='h');

# %%
plt.figure(figsize =(8,4))
sns.boxplot(x = 'area_worst', data=df1, orient='h');

# %%
for colname,colvals in df1.iteritems():
    if df1[colname].dtype!=object and colname!='diagnosis':
        Q1=df1[colname].quantile(q=0.25)
        Q3=df1[colname].quantile(q=0.75)
        IQR=Q3-Q1
        low=Q1-(1.5*IQR)
        up=Q3+(1.5*IQR)
        df1.loc[(df1[colname]<=low) | (df1[colname]>=up) ,colname]=df1[colname].median()
    

plt.figure(figsize =(8,4))
sns.boxplot(x = 'area_mean', data=df1, orient='h');

# %%
for colname,colvals in df1.iteritems():
    if df1[colname].dtype!=object and colname!='diagnosis':
        Q1=df1[colname].quantile(q=0.25)
        Q3=df1[colname].quantile(q=0.75)
        IQR=Q3-Q1
        low=Q1-(1.5*IQR)
        up=Q3+(1.5*IQR)
        df1.loc[(df1[colname]<=low) | (df1[colname]>=up) ,colname]=df1[colname].median()

plt.figure(figsize =(8,4))
sns.boxplot(x = 'area_worst', data=df1, orient='h');

# %% [markdown]
# #### This function remove the outliers of the features with the medians. Now Data is balanced for the further process.

# %% [markdown]
# # 6. Handling Categorical Data

# %%
df1=pd.get_dummies(df1,drop_first=True)
df1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90      551.1          0.08474
# 2        19.69         21.25          130.00      551.1          0.10960
# 3        11.42         20.38           77.58      386.1          0.09587
# 4        20.29         14.34          135.10      551.1          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.09263         0.06154              0.03350         0.2419
# 1           0.07864         0.08690              0.07017         0.1812
# 2           0.15990         0.19740              0.12790         0.2069
# 3           0.09263         0.24140              0.10520         0.1792
# 4           0.13280         0.19800              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# #### Machine learning models require all input and output variables to be numeric. This means that if your data contains categorical data, you must encode it to numbers before you can fit and evaluate a model.

# %% [markdown]
# # 7. Machine Learning

# %%
X=df1.drop(['diagnosis_M'],axis=1)
y=df1['diagnosis_M']

# %% [markdown]
# > Select X & y
# > X=independent columns
# > y=Dependent columns(Traget columns)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %% [markdown]
# ### Stadardization
# <blockquote>To comes all Data into one unit excpet Traget columns.Data comes in between(0,1)</blockquote>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %% [markdown]
# > Split the Data in Traininig and Testing

# %%
print('The shape of X_train is ',X_train.shape)
print('The shape of y_train is ',y_train.shape)
print('The shape of X_test is ',X_test.shape)
print('The shape of y_test is ',y_test.shape)
# Out:
# The shape of X_train is  (455, 30)
# The shape of y_train is  (455,)
# The shape of X_test is  (114, 30)
# The shape of y_test is  (114,)

# %%
from sklearn.linear_model import LogisticRegression


lr = LogisticRegression()


lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# > Model selection
# > Import the model
# > Instatiate the model
# > Fit the model with the data

# %%
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

# %% [markdown]
# >Prediction of test

# %%
from sklearn import metrics
print('Accuracy of training: ',metrics.accuracy_score(y_train,y_train_pred))
print('Accuracy of testing: ',metrics.accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy of training:  0.9692307692307692
# Accuracy of testing:  0.9824561403508771

# %% [markdown]
# <blockquote>Accuraracy of Traing and Testing</blockquote>

# %% [markdown]
# #### Confusion Matrix of Training Data.

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(y_test,y_test_pred)
print(cfm)
# Out:
# [[70  1]
#  [ 1 42]]

# %%
sns.heatmap(pd.DataFrame(cfm), annot=True,cmap="YlGnBu" ,fmt='g');
plt.tight_layout();
plt.title('Confusion matrix for Training', y=1.1);
plt.ylabel('Actual label');
plt.xlabel('Predicted label');

# %% [markdown]
# <blockquote>Confusing Metrix Of Traing Data</blockquote>

# %%
cnf=confusion_matrix(y_test,y_test_pred)
print(cnf)
# Out:
# [[70  1]
#  [ 1 42]]

# %%
sns.heatmap(pd.DataFrame(cnf), annot=True,cmap="YlGnBu" ,fmt='g');
plt.tight_layout();
plt.title('Confusion matrix for Testing', y=1.1);
plt.ylabel('Actual label');
plt.xlabel('Predicted label');

# %% [markdown]
# <blockquote>Confusing Metrix Of Testing Data</blockquote>

# %%
from sklearn import metrics
print("Training Precision:",metrics.precision_score(y_train,y_train_pred))
print("Testing Precision:",metrics.precision_score(y_test,y_test_pred))
print("Training Recall:",metrics.recall_score(y_train,y_train_pred))
print("Testing Recall:",metrics.recall_score(y_test,y_test_pred))
# Out:
# Training Precision: 0.9696969696969697
# Testing Precision: 0.9767441860465116
# Training Recall: 0.9467455621301775
# Testing Recall: 0.9767441860465116

# %%
Training_result=metrics.classification_report(y_train,y_train_pred)
print(Training_result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       286
#            1       0.97      0.95      0.96       169
#
#     accuracy                           0.97       455
#    macro avg       0.97      0.96      0.97       455
# weighted avg       0.97      0.97      0.97       455

# %%
Testing_result=metrics.classification_report(y_test,y_test_pred)
print(Testing_result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
y_pred_proba = lr.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.show()

# %% [markdown]
# ### Logistic regression is an example of supervised learning. It is used to calculate or predict the probability of a binary (yes/no) event occurring. An example of logistic regression could be applying machine learning to determine if a person is likely to be infected with Breast Cancer or not.

# %% [markdown]
# ### Curve is another common tool used with binary classifiers. The dotted line represents the Receiver operating characteristic (ROC) curve of a purely random classifier; a good classifier stays as far away from that line as possible

# %% [markdown]
# # Thanks You.
